# %% [markdown]
# # Exercise 1: Prime Numbers

# %% [markdown]
# ### Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
num= int(input("enter your number"))
for i in range(2,num):
    if num%i==0:
        print("it is not prime number")
        break
else:
    print("it is prime number")
# Out:
# enter your number 5
# it is prime number

# %% [markdown]
# # Exercise 2: Product of Random Numbers
#
# ### Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random

# %%
num1=random.randint(1,10)
num2=random.randint(1,10)

product_num=num1*num2
user_input=int(input("enter the product of num1 and num2"))
if user_input==product_num:
    print(" The user enter number is correct")
else:
    print(" The user enter number is wrong")
# Out:
# enter the product of num1 and num2 12
#  The user enter number is wrong

# %% [markdown]
# # Exercise 3: Squares of Even/Odd Numbers
# ### Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
# for the evne numbers
for i in range(100, 201):
    if i%2==0:
        print("even number=",i,"       " "squared number=", i*i)
# Out:
# even number= 100        squared number= 10000
# even number= 102        squared number= 10404
# even number= 104        squared number= 10816
# even number= 106        squared number= 11236
# even number= 108        squared number= 11664
# even number= 110        squared number= 12100
# even number= 112        squared number= 12544
# even number= 114        squared number= 12996
# even number= 116        squared number= 13456
# even number= 118        squared number= 13924
# even number= 120        squared number= 14400
# even number= 122        squared number= 14884
# even number= 124        squared number= 15376
# even number= 126        squared number= 15876
# even number= 128        squared number= 16384
# even number= 130        squared number= 16900
# even number= 132        squared number= 17424
# even number= 134        squared number= 17956
# even number= 136        squared number= 18496
# even number= 138        squared number= 19044
# even number= 140        squared number= 19600
# even number= 142        squared number= 20164
# even number= 144        squared number= 20736
# even number= 146        squared number= 21316
# even number= 148        squared number= 21904
# even number= 150        squared number= 22500
# even number= 152        squared number= 23104
# even number= 154        squared number= 23716
# even number= 156        squared number= 24336
# even number= 158        squared number= 24964
# even number= 160        squared number= 25600
# even number= 162        squared number= 26244
# even number= 164        squared number= 26896
# even number= 166        squared number= 27556
# even number= 168        squared number= 28224
# even number= 170        squared number= 28900
# even number= 172        squared number= 29584
# even number= 174        squared number= 30276
# even number= 176        squared number= 30976
# even number= 178        squared number= 31684
# even number= 180        squared number= 32400
# even number= 182        squared number= 33124
# even number= 184        squared number= 33856
# even number= 186        squared number= 34596
# even number= 188        squared number= 35344
# even number= 190        squared number= 36100
# even number= 192        squared number= 36864
# even number= 194        squared number= 37636
# even number= 196        squared number= 38416
# even number= 198        squared number= 39204
# even number= 200        squared number= 40000

# %% [markdown]
# # Exercise 4:
# ### ✅ Problem Statement (Question): Hospital Billing System
# ### A hospital charges its patients based on the following:
# ### •	Room charges per day: ₹2,000
# ### •	Doctor consultation fee (flat): ₹1,500
# ### •	Lab test charges: Based on the number of tests taken. Each test costs ₹300
# ### •	Medicine charges: Total cost of medicines provided
# ### •	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# ### Write a Python program to calculate the final bill for a patient who:
# ### •	Stayed for 4 days
# ### •	Had 3 lab tests
# ### •	Had medicine charges of ₹2,400

# %%
Room_charge_per_day=2000
Doctor_cosnultation_fee=1500
Lab_test_charges=300
Had_medicine_charges=2400

Discount=10000

# Stayed for 4 days
stayed_for_4days=Room_charge_per_day*4
print("total of Stayed for 4 days =","₹",stayed_for_4days)

#  Had 3 lab tests
lab_test_cost=Lab_test_charges*3
print("total lab test cost =", "₹",lab_test_cost)

# Final bill
Final_Bill=stayed_for_4days+lab_test_cost+Had_medicine_charges
print("Final_Bill is=", "₹",Final_Bill)

# Applied 10% Discount
if Final_Bill>10000:
    discount=Final_Bill*0.10
    final_amount=Final_Bill-discount
    print("After_appling_discount=", "₹",final_amount)
else:
    print('No Discount Applied')
# Out:
# total of Stayed for 4 days = ₹ 8000
# total lab test cost = ₹ 900
# Final_Bill is= ₹ 11300
# After_appling_discount= ₹ 10170.0
